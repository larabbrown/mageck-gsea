# %% [markdown]
# # Mageck Pipeline
#
# Lara Brown

# %%
from datetime import datetime
from IPython.display import display, Markdown

todays_date = str(datetime.now().date())

display(Markdown(f'##### Last updated: {todays_date}'))
# Out:
# ##### Last updated: 2023-06-01

# %% [markdown]
# ## Overview
#
# Run [MAGeCK](https://sourceforge.net/p/mageck/wiki/Home/) on read count tables from editing screens in order to quantify the effects of gene knockouts. For example, running MAGeCK on an apoliposecretion screen would indicate which genes impair or increase apolipoprotein secretion.
#
# The MAGeCK outputs can then be run through co-essential GSEA (gene set enrichment analysis).
#
# ## Requirements
#
# You will need a conda environment with MAGeCK installed and properly functioning, as well as access to Jupyter lab. Further, you will need a count table with the following characteristics:
#
# * Each row should correspond to a different gene that was knocked out in the screen
# * Columns should represent one apolipoprotein whose secretion was measured as part of the screen. Columns should also each correspond to...
#     * One of a number of replicates for that apolipoprotein
#     * One of (usually 4) bins, where each bin represents quantiles of cells with the strongest/least strong observed phenotypes (eg apolipoprotein secretion/uptake)
#     * As an example: APOC3_r2_T20 represents the top 20% of cells in terms of APOC3 secretion, from the second replicate
# * There should also be rows for control sgRNAs, identifiable somehow by name

# %% [markdown]
# ## Data Prep

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Ellie_mageck_count_table_RPM_020723_goodreps.txt", sep="\t")

# %%
df.head(5)
# Out:
#      sgrna  gene  AHSG_r1_B20  AHSG_r1_B40  AHSG_r1_T20  AHSG_r1_T40  \
# 0  A1CF__1  A1CF     0.000000     0.000000    65.316060     1.023492
# 1  A1CF__2  A1CF   250.507708   150.713025    46.654328    68.573943
# 2  AAAS__3  AAAS     1.912273    26.708637    80.030117    68.062198
# 3  AAAS__4  AAAS   124.297718   103.019030    53.473038    48.615855
# 4  AAMP__5  AAMP     5.736818    30.524157    59.215109    26.610784
#
#    AHSG_r2_B20  AHSG_r2_B40  AHSG_r2_T20  AHSG_r2_T40  ...  APOC3_r2_T20  \
# 0   107.847608    84.860934    53.609688   177.405595  ...     70.181546
# 1     3.081360    79.869114    80.414532   163.976486  ...     99.189918
# 2    27.732242   131.035266    78.565922   103.898894  ...     77.667577
# 3     0.000000    99.836393    54.533993    37.460146  ...     91.703886
# 4   251.130859    93.596619    14.788880    12.722314  ...    145.977615
#
#    APOC3_r2_T40  APOC3_r3_B20  APOC3_r3_B40  APOC3_r3_T20  APOC3_r3_T40  \
# 0     91.728545     26.275408     74.672085     31.395158     71.159598
# 1     95.315695     77.324773     37.948109     55.655053     54.827887
# 2     81.991996    138.884301     94.258206     51.373895    122.487833
# 3     69.693196     71.318965     75.896218    107.028948    205.312939
# 4    104.539794     69.066788    118.740857    111.310106     54.827887
#
#    APOC3_r4_B20  APOC3_r4_B40  APOC3_r4_T20  APOC3_r4_T40
# 0     78.472088    171.450615     51.067440    141.227615
# 1    100.806452    121.068197     94.278352     82.168794
# 2     63.381302     68.429851     78.565293     84.094625
# 3     39.236044      0.000000     62.852234     36.590791
# 4     37.425150     54.894276     99.516038     77.033244
#
# [5 rows x 58 columns]

# %% [markdown]
# ### Converting to reads per million
#
# Normalize the data columnwise so read counts are transformed into reads per million. (If data is already normalized, can skip this step, but also won't change results to repeat it.)

# %%
df = df.copy()
df.iloc[:,2:] = df.iloc[:,2:].apply(lambda x: (x/x.sum())*1000000, axis=0)

# %%
df.head()
# Out:
#      sgrna  gene  AHSG_r1_B20  AHSG_r1_B40  AHSG_r1_T20  AHSG_r1_T40  \
# 0  A1CF__1  A1CF     0.000000     0.000000    65.316060     1.023492
# 1  A1CF__2  A1CF   250.507708   150.713025    46.654328    68.573943
# 2  AAAS__3  AAAS     1.912273    26.708637    80.030117    68.062198
# 3  AAAS__4  AAAS   124.297718   103.019030    53.473038    48.615855
# 4  AAMP__5  AAMP     5.736818    30.524157    59.215109    26.610784
#
#    AHSG_r2_B20  AHSG_r2_B40  AHSG_r2_T20  AHSG_r2_T40  ...  APOC3_r2_T20  \
# 0   107.847608    84.860934    53.609688   177.405595  ...     70.181546
# 1     3.081360    79.869114    80.414532   163.976486  ...     99.189918
# 2    27.732242   131.035266    78.565922   103.898894  ...     77.667577
# 3     0.000000    99.836393    54.533993    37.460146  ...     91.703886
# 4   251.130859    93.596619    14.788879    12.722314  ...    145.977615
#
#    APOC3_r2_T40  APOC3_r3_B20  APOC3_r3_B40  APOC3_r3_T20  APOC3_r3_T40  \
# 0     91.728545     26.275408     74.672085     31.395158     71.159598
# 1     95.315695     77.324773     37.948109     55.655053     54.827887
# 2     81.991996    138.884301     94.258206     51.373895    122.487833
# 3     69.693196     71.318965     75.896218    107.028948    205.312939
# 4    104.539794     69.066788    118.740857    111.310106     54.827887
#
#    APOC3_r4_B20  APOC3_r4_B40  APOC3_r4_T20  APOC3_r4_T40
# 0     78.472088    171.450615     51.067440    141.227615
# 1    100.806452    121.068197     94.278352     82.168794
# 2     63.381302     68.429851     78.565293     84.094625
# 3     39.236044      0.000000     62.852234     36.590791
# 4     37.425150     54.894276     99.516038     77.033244
#
# [5 rows x 58 columns]

# %% [markdown]
# ### Creating weighted sums
#
# We experimented with different ways to combine or choose inputs for MAGeCK and ultimately settled on using a weighted sum of the top samples vs a weighted sum of the bottom.
#
# To calculate, double the top/bottom 20% bin RPMs before adding to next 40% bin RPMs. Calling this weighted top or bottom (WTOP/WBOT).
#
# groupby info: https://pandas.pydata.org/docs/user_guide/groupby.html
#
# regex info: https://docs.python.org/3/library/re.html

# %%
replicate = "(^[^_]*_[^_]*_)" # match everything up to second underscore
grouped = df.iloc[:,2:].groupby(df.iloc[:,2:].columns.str.extract(replicate, expand=False), axis=1)

# %%
for name,group in grouped:
    t20 = name + "T20"
    t40 = name + "T40"
    b20 = name + "B20"
    b40 = name + "B40"
    df[name + "WTOP"] = 2*group[t20] + group[t40]
    df[name + "WBOT"] = 2*group[b20] + group[b40]
    df[name + "SUMTOP"] = group[t20] + group[t40]
    df[name + "SUMBOT"] = group[b20] + group[b40]

# %%
df.head(5)
# Out:
#      sgrna  gene  AHSG_r1_B20  AHSG_r1_B40  AHSG_r1_T20  AHSG_r1_T40  \
# 0  A1CF__1  A1CF     0.000000     0.000000    65.316060     1.023492
# 1  A1CF__2  A1CF   250.507708   150.713025    46.654328    68.573943
# 2  AAAS__3  AAAS     1.912273    26.708637    80.030117    68.062198
# 3  AAAS__4  AAAS   124.297718   103.019030    53.473038    48.615855
# 4  AAMP__5  AAMP     5.736818    30.524157    59.215109    26.610784
#
#    AHSG_r2_B20  AHSG_r2_B40  AHSG_r2_T20  AHSG_r2_T40  ...  IGFBP1_r2_SUMTOP  \
# 0   107.847608    84.860934    53.609688   177.405595  ...         58.536665
# 1     3.081360    79.869114    80.414532   163.976486  ...        158.270589
# 2    27.732242   131.035266    78.565922   103.898894  ...        127.951606
# 3     0.000000    99.836393    54.533993    37.460146  ...        247.283466
# 4   251.130859    93.596619    14.788879    12.722314  ...        114.500341
#
#    IGFBP1_r2_SUMBOT  IGFBP1_r3_WTOP  IGFBP1_r3_WBOT  IGFBP1_r3_SUMTOP  \
# 0        195.186389      213.212464      317.546558        142.306747
# 1        147.328142      209.510771      238.539599        146.946904
# 2        238.352092      391.013776      441.410512        261.715117
# 3         83.986718      161.310524      262.914211        119.601279
# 4        138.412625      313.507561      430.818360        200.892599
#
#    IGFBP1_r3_SUMBOT  IGFBP1_r4_WTOP  IGFBP1_r4_WBOT  IGFBP1_r4_SUMTOP  \
# 0        198.927575      161.671420      268.426947        104.576414
# 1        139.994597      295.171463      219.174474        200.013120
# 2        278.993750      232.549995      300.094510        162.767209
# 3        162.544303       66.921790       64.833695         54.234011
# 4        286.650673      430.993436      411.338568        310.459534
#
#    IGFBP1_r4_SUMBOT
# 0        166.985584
# 1        150.552375
# 2        237.439551
# 3         52.899417
# 4        256.192955
#
# [5 rows x 114 columns]

# %% [markdown]
# Save this dataframe, with data converted to RPM and with weighted sums already calculated, for use in MAGeCK analysis.

# %%
df.to_csv("Ellie_mageck_count_table_RPM_020723_goodreps_WSUM.txt", sep='\t', index=False)

# %% [markdown]
# ### Save control gRNAs to a text file
#
# We run MAGeCK with control gRNAs specified; to do so, we need a text file listing all of the control gRNA names. In this case, all controls either started with CONTROL_ or MCP_, so we just select all of those and save to a file.

# %%
gRNAs = df['sgrna'].tolist()

# %%
control_gRNAs = [g for g in gRNAs if g.startswith("CONTROL_") or g.startswith("MCP_")]

# %%
with open('Ellie_mageck_control_gRNAs_combined_020723.txt', 'w') as filehandle:
    for c in control_gRNAs:
        filehandle.write(f'{c}\n')

# %% [markdown]
# ## Mageck instructions
#
# 1. Install mageck into your conda environment: `conda install -c bioconda mageck`
#
# 2. Make sure you are in the directory where your files are stored and where you want the output to write!
#
# 3. Run a version of the following in your terminal. This includes first an analysis for APCO3, then a separate analysis for APOE as the apolipoproteins whose phenotypes are measured. Change parameters as needed for your files:
#
# ```mageck test -k rpm_weighted_sum_file.txt -t first_weighted_top_col,second_weighted_top_col,etc -c first_weighted_bot_col,second_weighted_bot_col,etc -n ./mageck_out/phenotype_protein_name/desired_output_filename --control-sgrna control_gRNA_list.txt --sort-criteria pos --norm-method control```
#
# What the options mean:
#
# - -k: the gRNA count table (in this case it’s a RPM table)
# - -t: treatment samples (in this case the “Top” samples)
# - -c: control samples (in this case the “Bot” samples)
# - -n: name of the output files
# - --control-sgrna: because we use control gRNAs for normalization we need to supply a list of control gRNAs
# - --sort-criteria pos: in the output “xxx.gene_summary.txt” the genes will be sorted by the log fold change [log2(top/Bot)] in decreasing order.
# - --norm-method control: use control gRNAs for normalization

# %% [markdown]
# ### Running Mageck for multiple genes
#
# The for loop below creates the necessary directories for Mageck's output and runs Mageck for each of the four genes specified in this particular read count file.

# %%
genes = ["AHSG", "APOA1", "APOC3", "IGFBP1"] 
# genes = ["APOA1", "APOC3"] 

for g in genes:
    top_groups = ",".join([col for col in df.columns if (col.startswith(g) and col.endswith("WTOP"))])
    bot_groups = ",".join([col for col in df.columns if (col.startswith(g) and col.endswith("WBOT"))])
    
    out_dir = f"./mageck_out/{g}"
    out_name = f"./mageck_out/{g}/Ellie_mageck_wsum_{g}_020723"
    # print(out_dir)
    # print(out_name)
    # print(top_groups)
    # print(bot_groups)
    
    mageck_cmd1 = "mageck test -k Ellie_mageck_count_table_RPM_020723_goodreps_WSUM.txt"
    mageck_cmd2 = f"-t {top_groups}"
    mageck_cmd3 = f"-c {bot_groups}"
    mageck_cmd4 = f"-n {out_name}"
    mageck_cmd5 = f"--control-sgrna Ellie_mageck_control_gRNAs_combined_020723.txt --sort-criteria pos --norm-method control"
    
    mageck_cmd = " ".join([mageck_cmd1, mageck_cmd2, mageck_cmd3, mageck_cmd4, mageck_cmd5])
    
    # !mkdir -p {out_dir}
    
    print(mageck_cmd)
    
    # !{mageck_cmd}
# Out:
# mageck test -k Ellie_mageck_count_table_RPM_020723_goodreps_WSUM.txt -t AHSG_r1_WTOP,AHSG_r2_WTOP,AHSG_r3_WTOP -c AHSG_r1_WBOT,AHSG_r2_WBOT,AHSG_r3_WBOT -n ./mageck_out/AHSG/Ellie_mageck_wsum_AHSG_020723 --control-sgrna Ellie_mageck_control_gRNAs_combined_020723.txt --sort-criteria pos --norm-method control
# INFO  @ Thu, 01 Jun 2023 13:33:20: Parameters: /Users/lbb34/miniconda3/envs/mageck-env/bin/mageck test -k Ellie_mageck_count_table_RPM_020723_goodreps_WSUM.txt -t AHSG_r1_WTOP,AHSG_r2_WTOP,AHSG_r3_WTOP -c AHSG_r1_WBOT,AHSG_r2_WBOT,AHSG_r3_WBOT -n ./mageck_out/AHSG/Ellie_mageck_wsum_AHSG_020723 --control-sgrna Ellie_mageck_control_gRNAs_combined_020723.txt --sort-criteria pos --norm-method control
# INFO  @ Thu, 01 Jun 2023 13:33:20: Welcome to MAGeCK v0.5.9.2. Command: test
# INFO  @ Thu, 01 Jun 2023 13:33:20: Loading count table from Ellie_mageck_count_table_RPM_020723_goodreps_WSUM.txt
# INFO  @ Thu, 01 Jun 2023 13:33:20: Processing 1 lines..
# INFO  @ Thu, 01 Jun 2023 13:33:21: Loaded 10330 records.
# INFO  @ Thu, 01 Jun 2023 13:33:21: Loading R template file: /Users/lbb34/miniconda3/envs/mageck-env/lib/python3.7/site-packages/mageck/plot_template.RTemplate.
# INFO  @ Thu, 01 Jun 2023 13:33:21: Loading R template file: /Users/lbb34/miniconda3/envs/mageck-env/lib/python3.7/site-packages/mageck/plot_template_indvgene.RTemplate.
# INFO  @ Thu, 01 Jun 2023 13:33:21: Loading Rnw template file: /Users/lbb34/miniconda3/envs/mageck-env/lib/python3.7/site-packages/mageck/plot_template.Rnw.
# INFO  @ Thu, 01 Jun 2023 13:33:21: Treatment samples:AHSG_r1_WTOP,AHSG_r2_WTOP,AHSG_r3_WTOP
# INFO  @ Thu, 01 Jun 2023 13:33:21: Treatment sample index:56,60,64
# INFO  @ Thu, 01 Jun 2023 13:33:21: Control samples:AHSG_r1_WBOT,AHSG_r2_WBOT,AHSG_r3_WBOT
# INFO  @ Thu, 01 Jun 2023 13:33:21: Control sample index:57,61,65
# INFO  @ Thu, 01 Jun 2023 13:33:21: Loaded 250 control sgRNAs from Ellie_mageck_control_gRNAs_combined_020723.txt
# INFO  @ Thu, 01 Jun 2023 13:33:21: control sgRNAs for normalization:250
# INFO  @ Thu, 01 Jun 2023 13:33:21: Final size factor: 1.0258146399533117 1.1191479486335736 0.8474012606070128 0.8999395788924863 1.066143628252203 0.9084530427097866
# INFO  @ Thu, 01 Jun 2023 13:33:21: Detecting outliers from variance estimation.. Avg read count:[215.30598715920377], Var: [30013.979095623163]
# INFO  @ Thu, 01 Jun 2023 13:33:21: Skipping 61 sgRNAs from variance calculation because of their extreme high counts (> 4* STD (mean counts) ).
# INFO  @ Thu, 01 Jun 2023 13:33:21: Before RRA, 1 sgRNAs are removed with zero counts in both group(s).
# INFO  @ Thu, 01 Jun 2023 13:33:21: Use qnorm to reversely calculate sgRNA scores ...
# INFO  @ Thu, 01 Jun 2023 13:33:21: Running command: RRA -i ./mageck_out/AHSG/Ellie_mageck_wsum_AHSG_020723.plow.txt -o ./mageck_out/AHSG/Ellie_mageck_wsum_AHSG_020723.gene.low.txt -p 0.12401975021783329 --control Ellie_mageck_control_gRNAs_combined_020723.txt --skip-gene NA --skip-gene na
# INFO  @ Thu, 01 Jun 2023 13:33:21: Command message:
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Welcome to RRA v 0.5.9.
# INFO  @ Thu, 01 Jun 2023 13:33:21:   251 control sequences loaded.
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Skipping gene NA for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Skipping gene na for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Reading input file...
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Summary: 10329 sgRNAs, 5042 genes, 1 lists; skipped sgRNAs:0
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Computing lo-values for each group...
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Skipping gene MCP for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Skipping gene CONTROL for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Warning: sgRNA  not found in the ranked list.
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Computing false discovery rate...
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Total # control sgRNAs: 250
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Permuting genes with 1 sgRNAs...
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Permuting genes with 2 sgRNAs...
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Number of genes under FDR adjustment: 5042
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Saving to output file...
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Suppressing the output of gene CONTROL since it is negative ontrol genes.
# INFO  @ Thu, 01 Jun 2023 13:33:21:   Suppressing the output of gene MCP since it is negative ontrol genes.
# INFO  @ Thu, 01 Jun 2023 13:33:21:   RRA completed.
# INFO  @ Thu, 01 Jun 2023 13:33:21:
# INFO  @ Thu, 01 Jun 2023 13:33:21: End command message.
# INFO  @ Thu, 01 Jun 2023 13:33:21: Running command: RRA -i ./mageck_out/AHSG/Ellie_mageck_wsum_AHSG_020723.phigh.txt -o ./mageck_out/AHSG/Ellie_mageck_wsum_AHSG_020723.gene.high.txt -p 0.23903572465872786 --control Ellie_mageck_control_gRNAs_combined_020723.txt --skip-gene NA --skip-gene na
# INFO  @ Thu, 01 Jun 2023 13:33:22: Command message:
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Welcome to RRA v 0.5.9.
# INFO  @ Thu, 01 Jun 2023 13:33:22:   251 control sequences loaded.
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Skipping gene NA for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Skipping gene na for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Reading input file...
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Summary: 10329 sgRNAs, 5042 genes, 1 lists; skipped sgRNAs:0
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Computing lo-values for each group...
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Skipping gene CONTROL for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Skipping gene MCP for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Warning: sgRNA  not found in the ranked list.
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Computing false discovery rate...
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Total # control sgRNAs: 250
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Permuting genes with 1 sgRNAs...
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Permuting genes with 2 sgRNAs...
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Number of genes under FDR adjustment: 5042
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Saving to output file...
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Suppressing the output of gene CONTROL since it is negative ontrol genes.
# INFO  @ Thu, 01 Jun 2023 13:33:22:   Suppressing the output of gene MCP since it is negative ontrol genes.
# INFO  @ Thu, 01 Jun 2023 13:33:22:   RRA completed.
# INFO  @ Thu, 01 Jun 2023 13:33:22:
# INFO  @ Thu, 01 Jun 2023 13:33:22: End command message.
# INFO  @ Thu, 01 Jun 2023 13:33:22: Loading top 10 genes from ./mageck_out/AHSG/Ellie_mageck_wsum_AHSG_020723.gene.low.txt: ITPA,ZC3H3,MNT,PLCXD3,INHA,DCAF12,PTEN,UBA52,FXR2,C1GALT1C1
# INFO  @ Thu, 01 Jun 2023 13:33:22: Loading top 10 genes from ./mageck_out/AHSG/Ellie_mageck_wsum_AHSG_020723.gene.high.txt: C1orf210,EIF2B4,RPS23,SLC22A17,NELL1,RPL9,TRA2B,UTP20,NIFK,USP35
# INFO  @ Thu, 01 Jun 2023 13:33:22: Running command: rm ./mageck_out/AHSG/Ellie_mageck_wsum_AHSG_020723.plow.txt
# INFO  @ Thu, 01 Jun 2023 13:33:22: Running command: rm ./mageck_out/AHSG/Ellie_mageck_wsum_AHSG_020723.phigh.txt
# INFO  @ Thu, 01 Jun 2023 13:33:22: Running command: rm ./mageck_out/AHSG/Ellie_mageck_wsum_AHSG_020723.gene.low.txt
# INFO  @ Thu, 01 Jun 2023 13:33:22: Running command: rm ./mageck_out/AHSG/Ellie_mageck_wsum_AHSG_020723.gene.high.txt
# mageck test -k Ellie_mageck_count_table_RPM_020723_goodreps_WSUM.txt -t APOA1_r2_WTOP,APOA1_r3_WTOP,APOA1_r4_WTOP -c APOA1_r2_WBOT,APOA1_r3_WBOT,APOA1_r4_WBOT -n ./mageck_out/APOA1/Ellie_mageck_wsum_APOA1_020723 --control-sgrna Ellie_mageck_control_gRNAs_combined_020723.txt --sort-criteria pos --norm-method control
# INFO  @ Thu, 01 Jun 2023 13:33:23: Parameters: /Users/lbb34/miniconda3/envs/mageck-env/bin/mageck test -k Ellie_mageck_count_table_RPM_020723_goodreps_WSUM.txt -t APOA1_r2_WTOP,APOA1_r3_WTOP,APOA1_r4_WTOP -c APOA1_r2_WBOT,APOA1_r3_WBOT,APOA1_r4_WBOT -n ./mageck_out/APOA1/Ellie_mageck_wsum_APOA1_020723 --control-sgrna Ellie_mageck_control_gRNAs_combined_020723.txt --sort-criteria pos --norm-method control
# INFO  @ Thu, 01 Jun 2023 13:33:23: Welcome to MAGeCK v0.5.9.2. Command: test
# INFO  @ Thu, 01 Jun 2023 13:33:23: Loading count table from Ellie_mageck_count_table_RPM_020723_goodreps_WSUM.txt
# INFO  @ Thu, 01 Jun 2023 13:33:23: Processing 1 lines..
# INFO  @ Thu, 01 Jun 2023 13:33:23: Loaded 10330 records.
# INFO  @ Thu, 01 Jun 2023 13:33:23: Loading R template file: /Users/lbb34/miniconda3/envs/mageck-env/lib/python3.7/site-packages/mageck/plot_template.RTemplate.
# INFO  @ Thu, 01 Jun 2023 13:33:23: Loading R template file: /Users/lbb34/miniconda3/envs/mageck-env/lib/python3.7/site-packages/mageck/plot_template_indvgene.RTemplate.
# INFO  @ Thu, 01 Jun 2023 13:33:23: Loading Rnw template file: /Users/lbb34/miniconda3/envs/mageck-env/lib/python3.7/site-packages/mageck/plot_template.Rnw.
# INFO  @ Thu, 01 Jun 2023 13:33:23: Treatment samples:APOA1_r2_WTOP,APOA1_r3_WTOP,APOA1_r4_WTOP
# INFO  @ Thu, 01 Jun 2023 13:33:23: Treatment sample index:68,72,76
# INFO  @ Thu, 01 Jun 2023 13:33:23: Control samples:APOA1_r2_WBOT,APOA1_r3_WBOT,APOA1_r4_WBOT
# INFO  @ Thu, 01 Jun 2023 13:33:23: Control sample index:69,73,77
# INFO  @ Thu, 01 Jun 2023 13:33:23: Loaded 250 control sgRNAs from Ellie_mageck_control_gRNAs_combined_020723.txt
# INFO  @ Thu, 01 Jun 2023 13:33:23: control sgRNAs for normalization:250
# INFO  @ Thu, 01 Jun 2023 13:33:23: Final size factor: 0.9897636060677485 0.9161054783094116 0.9989599134723317 1.0121702200440281 0.9728396935856322 1.0076468294572847
# INFO  @ Thu, 01 Jun 2023 13:33:23: Detecting outliers from variance estimation.. Avg read count:[244.0834279560959], Var: [20967.744439031183]
# INFO  @ Thu, 01 Jun 2023 13:33:23: Skipping 23 sgRNAs from variance calculation because of their extreme high counts (> 4* STD (mean counts) ).
# INFO  @ Thu, 01 Jun 2023 13:33:23: Before RRA, 2 sgRNAs are removed with zero counts in both group(s).
# INFO  @ Thu, 01 Jun 2023 13:33:23: Use qnorm to reversely calculate sgRNA scores ...
# INFO  @ Thu, 01 Jun 2023 13:33:24: Running command: RRA -i ./mageck_out/APOA1/Ellie_mageck_wsum_APOA1_020723.plow.txt -o ./mageck_out/APOA1/Ellie_mageck_wsum_APOA1_020723.gene.low.txt -p 0.11589852827265686 --control Ellie_mageck_control_gRNAs_combined_020723.txt --skip-gene NA --skip-gene na
# INFO  @ Thu, 01 Jun 2023 13:33:24: Command message:
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Welcome to RRA v 0.5.9.
# INFO  @ Thu, 01 Jun 2023 13:33:24:   251 control sequences loaded.
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Skipping gene NA for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Skipping gene na for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Reading input file...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Summary: 10328 sgRNAs, 5042 genes, 1 lists; skipped sgRNAs:0
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Computing lo-values for each group...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Skipping gene MCP for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Skipping gene CONTROL for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Warning: sgRNA  not found in the ranked list.
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Computing false discovery rate...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Total # control sgRNAs: 250
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Permuting genes with 1 sgRNAs...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Permuting genes with 2 sgRNAs...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Number of genes under FDR adjustment: 5042
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Saving to output file...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Suppressing the output of gene MCP since it is negative ontrol genes.
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Suppressing the output of gene CONTROL since it is negative ontrol genes.
# INFO  @ Thu, 01 Jun 2023 13:33:24:   RRA completed.
# INFO  @ Thu, 01 Jun 2023 13:33:24:
# INFO  @ Thu, 01 Jun 2023 13:33:24: End command message.
# INFO  @ Thu, 01 Jun 2023 13:33:24: Running command: RRA -i ./mageck_out/APOA1/Ellie_mageck_wsum_APOA1_020723.phigh.txt -o ./mageck_out/APOA1/Ellie_mageck_wsum_APOA1_020723.gene.high.txt -p 0.2487412858249419 --control Ellie_mageck_control_gRNAs_combined_020723.txt --skip-gene NA --skip-gene na
# INFO  @ Thu, 01 Jun 2023 13:33:24: Command message:
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Welcome to RRA v 0.5.9.
# INFO  @ Thu, 01 Jun 2023 13:33:24:   251 control sequences loaded.
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Skipping gene NA for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Skipping gene na for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Reading input file...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Summary: 10328 sgRNAs, 5042 genes, 1 lists; skipped sgRNAs:0
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Computing lo-values for each group...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Skipping gene CONTROL for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Skipping gene MCP for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Warning: sgRNA  not found in the ranked list.
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Computing false discovery rate...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Total # control sgRNAs: 250
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Permuting genes with 1 sgRNAs...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Permuting genes with 2 sgRNAs...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Number of genes under FDR adjustment: 5042
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Saving to output file...
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Suppressing the output of gene MCP since it is negative ontrol genes.
# INFO  @ Thu, 01 Jun 2023 13:33:24:   Suppressing the output of gene CONTROL since it is negative ontrol genes.
# INFO  @ Thu, 01 Jun 2023 13:33:24:   RRA completed.
# INFO  @ Thu, 01 Jun 2023 13:33:24:
# INFO  @ Thu, 01 Jun 2023 13:33:24: End command message.
# INFO  @ Thu, 01 Jun 2023 13:33:24: Loading top 10 genes from ./mageck_out/APOA1/Ellie_mageck_wsum_APOA1_020723.gene.low.txt: ARL4C,P2RY11,CEP41,FBXO42,TRPM4,CABP1,REEP4,SARM1,TMEM192,CACNG3
# INFO  @ Thu, 01 Jun 2023 13:33:24: Loading top 10 genes from ./mageck_out/APOA1/Ellie_mageck_wsum_APOA1_020723.gene.high.txt: DNLZ,PREB,RAF1,BUB3,RPL27A,NDUFB1,MRPS11,MRPL57,ZNRF1,U2AF2
# INFO  @ Thu, 01 Jun 2023 13:33:24: Running command: rm ./mageck_out/APOA1/Ellie_mageck_wsum_APOA1_020723.plow.txt
# INFO  @ Thu, 01 Jun 2023 13:33:24: Running command: rm ./mageck_out/APOA1/Ellie_mageck_wsum_APOA1_020723.phigh.txt
# INFO  @ Thu, 01 Jun 2023 13:33:24: Running command: rm ./mageck_out/APOA1/Ellie_mageck_wsum_APOA1_020723.gene.low.txt
# INFO  @ Thu, 01 Jun 2023 13:33:24: Running command: rm ./mageck_out/APOA1/Ellie_mageck_wsum_APOA1_020723.gene.high.txt
# mageck test -k Ellie_mageck_count_table_RPM_020723_goodreps_WSUM.txt -t APOC3_r1_WTOP,APOC3_r2_WTOP,APOC3_r3_WTOP,APOC3_r4_WTOP -c APOC3_r1_WBOT,APOC3_r2_WBOT,APOC3_r3_WBOT,APOC3_r4_WBOT -n ./mageck_out/APOC3/Ellie_mageck_wsum_APOC3_020723 --control-sgrna Ellie_mageck_control_gRNAs_combined_020723.txt --sort-criteria pos --norm-method control
# INFO  @ Thu, 01 Jun 2023 13:33:25: Parameters: /Users/lbb34/miniconda3/envs/mageck-env/bin/mageck test -k Ellie_mageck_count_table_RPM_020723_goodreps_WSUM.txt -t APOC3_r1_WTOP,APOC3_r2_WTOP,APOC3_r3_WTOP,APOC3_r4_WTOP -c APOC3_r1_WBOT,APOC3_r2_WBOT,APOC3_r3_WBOT,APOC3_r4_WBOT -n ./mageck_out/APOC3/Ellie_mageck_wsum_APOC3_020723 --control-sgrna Ellie_mageck_control_gRNAs_combined_020723.txt --sort-criteria pos --norm-method control
# INFO  @ Thu, 01 Jun 2023 13:33:25: Welcome to MAGeCK v0.5.9.2. Command: test
# INFO  @ Thu, 01 Jun 2023 13:33:25: Loading count table from Ellie_mageck_count_table_RPM_020723_goodreps_WSUM.txt
# INFO  @ Thu, 01 Jun 2023 13:33:25: Processing 1 lines..
# INFO  @ Thu, 01 Jun 2023 13:33:26: Loaded 10330 records.
# INFO  @ Thu, 01 Jun 2023 13:33:26: Loading R template file: /Users/lbb34/miniconda3/envs/mageck-env/lib/python3.7/site-packages/mageck/plot_template.RTemplate.
# INFO  @ Thu, 01 Jun 2023 13:33:26: Loading R template file: /Users/lbb34/miniconda3/envs/mageck-env/lib/python3.7/site-packages/mageck/plot_template_indvgene.RTemplate.
# INFO  @ Thu, 01 Jun 2023 13:33:26: Loading Rnw template file: /Users/lbb34/miniconda3/envs/mageck-env/lib/python3.7/site-packages/mageck/plot_template.Rnw.
# INFO  @ Thu, 01 Jun 2023 13:33:26: Treatment samples:APOC3_r1_WTOP,APOC3_r2_WTOP,APOC3_r3_WTOP,APOC3_r4_WTOP
# INFO  @ Thu, 01 Jun 2023 13:33:26: Treatment sample index:80,84,88,92
# INFO  @ Thu, 01 Jun 2023 13:33:26: Control samples:APOC3_r1_WBOT,APOC3_r2_WBOT,APOC3_r3_WBOT,APOC3_r4_WBOT
# INFO  @ Thu, 01 Jun 2023 13:33:26: Control sample index:81,85,89,93
# INFO  @ Thu, 01 Jun 2023 13:33:26: Loaded 250 control sgRNAs from Ellie_mageck_control_gRNAs_combined_020723.txt
# INFO  @ Thu, 01 Jun 2023 13:33:26: control sgRNAs for normalization:250
# INFO  @ Thu, 01 Jun 2023 13:33:26: Final size factor: 0.948049675242362 0.9557163232484019 0.9360976116776274 0.969765512802875 1.047998343826198 1.0179899586975898 1.0207356471956115 1.0277397399628263
# INFO  @ Thu, 01 Jun 2023 13:33:26: Detecting outliers from variance estimation.. Avg read count:[266.5463606192717], Var: [10849.607714375525]
# INFO  @ Thu, 01 Jun 2023 13:33:26: Skipping 6 sgRNAs from variance calculation because of their extreme high counts (> 4* STD (mean counts) ).
# INFO  @ Thu, 01 Jun 2023 13:33:26: Before RRA, 1 sgRNAs are removed with zero counts in both group(s).
# INFO  @ Thu, 01 Jun 2023 13:33:26: Use qnorm to reversely calculate sgRNA scores ...
# INFO  @ Thu, 01 Jun 2023 13:33:26: Running command: RRA -i ./mageck_out/APOC3/Ellie_mageck_wsum_APOC3_020723.plow.txt -o ./mageck_out/APOC3/Ellie_mageck_wsum_APOC3_020723.gene.low.txt -p 0.1336044147545745 --control Ellie_mageck_control_gRNAs_combined_020723.txt --skip-gene NA --skip-gene na
# INFO  @ Thu, 01 Jun 2023 13:33:26: Command message:
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Welcome to RRA v 0.5.9.
# INFO  @ Thu, 01 Jun 2023 13:33:26:   251 control sequences loaded.
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Skipping gene NA for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Skipping gene na for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Reading input file...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Summary: 10329 sgRNAs, 5042 genes, 1 lists; skipped sgRNAs:0
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Computing lo-values for each group...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Skipping gene CONTROL for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Skipping gene MCP for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Warning: sgRNA  not found in the ranked list.
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Computing false discovery rate...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Total # control sgRNAs: 250
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Permuting genes with 1 sgRNAs...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Permuting genes with 2 sgRNAs...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Number of genes under FDR adjustment: 5042
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Saving to output file...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Suppressing the output of gene CONTROL since it is negative ontrol genes.
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Suppressing the output of gene MCP since it is negative ontrol genes.
# INFO  @ Thu, 01 Jun 2023 13:33:26:   RRA completed.
# INFO  @ Thu, 01 Jun 2023 13:33:26:
# INFO  @ Thu, 01 Jun 2023 13:33:26: End command message.
# INFO  @ Thu, 01 Jun 2023 13:33:26: Running command: RRA -i ./mageck_out/APOC3/Ellie_mageck_wsum_APOC3_020723.phigh.txt -o ./mageck_out/APOC3/Ellie_mageck_wsum_APOC3_020723.gene.high.txt -p 0.34814599670829705 --control Ellie_mageck_control_gRNAs_combined_020723.txt --skip-gene NA --skip-gene na
# INFO  @ Thu, 01 Jun 2023 13:33:26: Command message:
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Welcome to RRA v 0.5.9.
# INFO  @ Thu, 01 Jun 2023 13:33:26:   251 control sequences loaded.
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Skipping gene NA for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Skipping gene na for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Reading input file...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Summary: 10329 sgRNAs, 5042 genes, 1 lists; skipped sgRNAs:0
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Computing lo-values for each group...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Skipping gene MCP for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Skipping gene CONTROL for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Warning: sgRNA  not found in the ranked list.
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Computing false discovery rate...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Total # control sgRNAs: 250
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Permuting genes with 1 sgRNAs...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Permuting genes with 2 sgRNAs...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Number of genes under FDR adjustment: 5042
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Saving to output file...
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Suppressing the output of gene MCP since it is negative ontrol genes.
# INFO  @ Thu, 01 Jun 2023 13:33:26:   Suppressing the output of gene CONTROL since it is negative ontrol genes.
# INFO  @ Thu, 01 Jun 2023 13:33:26:   RRA completed.
# INFO  @ Thu, 01 Jun 2023 13:33:26:
# INFO  @ Thu, 01 Jun 2023 13:33:26: End command message.
# INFO  @ Thu, 01 Jun 2023 13:33:27: Loading top 10 genes from ./mageck_out/APOC3/Ellie_mageck_wsum_APOC3_020723.gene.low.txt: LHFPL4,TRIQK,SMUG1,VSX2,GM2A,FBXO28,UFC1,UBA52,GLYATL2,OST4
# INFO  @ Thu, 01 Jun 2023 13:33:27: Loading top 10 genes from ./mageck_out/APOC3/Ellie_mageck_wsum_APOC3_020723.gene.high.txt: KEAP1,PREB,RPS20,RPL9,RCL1,RPL13A,RPS4X,EIF2B4,ATP5F1B,HNF1A
# INFO  @ Thu, 01 Jun 2023 13:33:27: Running command: rm ./mageck_out/APOC3/Ellie_mageck_wsum_APOC3_020723.plow.txt
# INFO  @ Thu, 01 Jun 2023 13:33:27: Running command: rm ./mageck_out/APOC3/Ellie_mageck_wsum_APOC3_020723.phigh.txt
# INFO  @ Thu, 01 Jun 2023 13:33:27: Running command: rm ./mageck_out/APOC3/Ellie_mageck_wsum_APOC3_020723.gene.low.txt
# INFO  @ Thu, 01 Jun 2023 13:33:27: Running command: rm ./mageck_out/APOC3/Ellie_mageck_wsum_APOC3_020723.gene.high.txt
# mageck test -k Ellie_mageck_count_table_RPM_020723_goodreps_WSUM.txt -t IGFBP1_r1_WTOP,IGFBP1_r2_WTOP,IGFBP1_r3_WTOP,IGFBP1_r4_WTOP -c IGFBP1_r1_WBOT,IGFBP1_r2_WBOT,IGFBP1_r3_WBOT,IGFBP1_r4_WBOT -n ./mageck_out/IGFBP1/Ellie_mageck_wsum_IGFBP1_020723 --control-sgrna Ellie_mageck_control_gRNAs_combined_020723.txt --sort-criteria pos --norm-method control
# INFO  @ Thu, 01 Jun 2023 13:33:28: Parameters: /Users/lbb34/miniconda3/envs/mageck-env/bin/mageck test -k Ellie_mageck_count_table_RPM_020723_goodreps_WSUM.txt -t IGFBP1_r1_WTOP,IGFBP1_r2_WTOP,IGFBP1_r3_WTOP,IGFBP1_r4_WTOP -c IGFBP1_r1_WBOT,IGFBP1_r2_WBOT,IGFBP1_r3_WBOT,IGFBP1_r4_WBOT -n ./mageck_out/IGFBP1/Ellie_mageck_wsum_IGFBP1_020723 --control-sgrna Ellie_mageck_control_gRNAs_combined_020723.txt --sort-criteria pos --norm-method control
# INFO  @ Thu, 01 Jun 2023 13:33:28: Welcome to MAGeCK v0.5.9.2. Command: test
# INFO  @ Thu, 01 Jun 2023 13:33:28: Loading count table from Ellie_mageck_count_table_RPM_020723_goodreps_WSUM.txt
# INFO  @ Thu, 01 Jun 2023 13:33:28: Processing 1 lines..
# INFO  @ Thu, 01 Jun 2023 13:33:28: Loaded 10330 records.
# INFO  @ Thu, 01 Jun 2023 13:33:28: Loading R template file: /Users/lbb34/miniconda3/envs/mageck-env/lib/python3.7/site-packages/mageck/plot_template.RTemplate.
# INFO  @ Thu, 01 Jun 2023 13:33:28: Loading R template file: /Users/lbb34/miniconda3/envs/mageck-env/lib/python3.7/site-packages/mageck/plot_template_indvgene.RTemplate.
# INFO  @ Thu, 01 Jun 2023 13:33:28: Loading Rnw template file: /Users/lbb34/miniconda3/envs/mageck-env/lib/python3.7/site-packages/mageck/plot_template.Rnw.
# INFO  @ Thu, 01 Jun 2023 13:33:28: Treatment samples:IGFBP1_r1_WTOP,IGFBP1_r2_WTOP,IGFBP1_r3_WTOP,IGFBP1_r4_WTOP
# INFO  @ Thu, 01 Jun 2023 13:33:28: Treatment sample index:96,100,104,108
# INFO  @ Thu, 01 Jun 2023 13:33:28: Control samples:IGFBP1_r1_WBOT,IGFBP1_r2_WBOT,IGFBP1_r3_WBOT,IGFBP1_r4_WBOT
# INFO  @ Thu, 01 Jun 2023 13:33:28: Control sample index:97,101,105,109
# INFO  @ Thu, 01 Jun 2023 13:33:28: Loaded 250 control sgRNAs from Ellie_mageck_control_gRNAs_combined_020723.txt
# INFO  @ Thu, 01 Jun 2023 13:33:28: control sgRNAs for normalization:250
# INFO  @ Thu, 01 Jun 2023 13:33:28: Final size factor: 0.9681198791703673 0.9413369788116966 0.9540162936210387 0.9844242885295829 0.9802251203049367 1.0986679694126436 0.9804001827013114 1.0251786133515748
# INFO  @ Thu, 01 Jun 2023 13:33:28: Detecting outliers from variance estimation.. Avg read count:[265.99559462689336], Var: [10634.170804700168]
# INFO  @ Thu, 01 Jun 2023 13:33:28: Skipping 7 sgRNAs from variance calculation because of their extreme high counts (> 4* STD (mean counts) ).
# INFO  @ Thu, 01 Jun 2023 13:33:28: Before RRA, 1 sgRNAs are removed with zero counts in both group(s).
# INFO  @ Thu, 01 Jun 2023 13:33:28: Use qnorm to reversely calculate sgRNA scores ...
# INFO  @ Thu, 01 Jun 2023 13:33:28: Running command: RRA -i ./mageck_out/IGFBP1/Ellie_mageck_wsum_IGFBP1_020723.plow.txt -o ./mageck_out/IGFBP1/Ellie_mageck_wsum_IGFBP1_020723.gene.low.txt -p 0.14115596863200697 --control Ellie_mageck_control_gRNAs_combined_020723.txt --skip-gene NA --skip-gene na
# INFO  @ Thu, 01 Jun 2023 13:33:29: Command message:
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Welcome to RRA v 0.5.9.
# INFO  @ Thu, 01 Jun 2023 13:33:29:   251 control sequences loaded.
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Skipping gene NA for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Skipping gene na for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Reading input file...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Summary: 10329 sgRNAs, 5042 genes, 1 lists; skipped sgRNAs:0
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Computing lo-values for each group...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Skipping gene CONTROL for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Skipping gene MCP for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Warning: sgRNA  not found in the ranked list.
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Computing false discovery rate...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Total # control sgRNAs: 250
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Permuting genes with 1 sgRNAs...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Permuting genes with 2 sgRNAs...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Number of genes under FDR adjustment: 5042
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Saving to output file...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Suppressing the output of gene CONTROL since it is negative ontrol genes.
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Suppressing the output of gene MCP since it is negative ontrol genes.
# INFO  @ Thu, 01 Jun 2023 13:33:29:   RRA completed.
# INFO  @ Thu, 01 Jun 2023 13:33:29:
# INFO  @ Thu, 01 Jun 2023 13:33:29: End command message.
# INFO  @ Thu, 01 Jun 2023 13:33:29: Running command: RRA -i ./mageck_out/IGFBP1/Ellie_mageck_wsum_IGFBP1_020723.phigh.txt -o ./mageck_out/IGFBP1/Ellie_mageck_wsum_IGFBP1_020723.gene.high.txt -p 0.26866105140865526 --control Ellie_mageck_control_gRNAs_combined_020723.txt --skip-gene NA --skip-gene na
# INFO  @ Thu, 01 Jun 2023 13:33:29: Command message:
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Welcome to RRA v 0.5.9.
# INFO  @ Thu, 01 Jun 2023 13:33:29:   251 control sequences loaded.
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Skipping gene NA for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Skipping gene na for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Reading input file...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Summary: 10329 sgRNAs, 5042 genes, 1 lists; skipped sgRNAs:0
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Computing lo-values for each group...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Skipping gene CONTROL for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Skipping gene MCP for permutation ...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Warning: sgRNA  not found in the ranked list.
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Computing false discovery rate...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Total # control sgRNAs: 250
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Permuting genes with 1 sgRNAs...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Permuting genes with 2 sgRNAs...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Number of genes under FDR adjustment: 5042
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Saving to output file...
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Suppressing the output of gene MCP since it is negative ontrol genes.
# INFO  @ Thu, 01 Jun 2023 13:33:29:   Suppressing the output of gene CONTROL since it is negative ontrol genes.
# INFO  @ Thu, 01 Jun 2023 13:33:29:   RRA completed.
# INFO  @ Thu, 01 Jun 2023 13:33:29:
# INFO  @ Thu, 01 Jun 2023 13:33:29: End command message.
# INFO  @ Thu, 01 Jun 2023 13:33:29: Loading top 10 genes from ./mageck_out/IGFBP1/Ellie_mageck_wsum_IGFBP1_020723.gene.low.txt: MYL4,COL11A1,TSTD3,TMEM88,BRD2,TAF2,ADGRG5,XKR8,CWF19L1,GSDMD
# INFO  @ Thu, 01 Jun 2023 13:33:29: Loading top 10 genes from ./mageck_out/IGFBP1/Ellie_mageck_wsum_IGFBP1_020723.gene.high.txt: RABGAP1,VPS29,NDUFB2,POLD2,NDUFA13,EXOC1,RAF1,PXMP2,RPL23A,POLR2B
# INFO  @ Thu, 01 Jun 2023 13:33:29: Running command: rm ./mageck_out/IGFBP1/Ellie_mageck_wsum_IGFBP1_020723.plow.txt
# INFO  @ Thu, 01 Jun 2023 13:33:29: Running command: rm ./mageck_out/IGFBP1/Ellie_mageck_wsum_IGFBP1_020723.phigh.txt
# INFO  @ Thu, 01 Jun 2023 13:33:29: Running command: rm ./mageck_out/IGFBP1/Ellie_mageck_wsum_IGFBP1_020723.gene.low.txt
# INFO  @ Thu, 01 Jun 2023 13:33:29: Running command: rm ./mageck_out/IGFBP1/Ellie_mageck_wsum_IGFBP1_020723.gene.high.txt

# %% [markdown]
# ## After running MAGECK
#
# You'll be left with a number of different files, ideally stored in a nice directory depending on how you specified the output. In particular, we're looking for the file(s) of the form `{outputname}.gene_summary.txt`.
#
# The file is sorted by rank, but instead, sort it by lfc.
#
# To run co-essential GSEA on the results, navigate to `run_CE_gsea_loop.ipynb`.
